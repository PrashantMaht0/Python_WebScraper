# %%
import pandas as pd

df = pd.read_json("../data/processed_dataset/dataset.json")
df.head()
# Out:
#          id                                          url  \
# 0  site_000                       https://www.amazon.ie/
# 1  site_001  https://www.dailymail.co.uk/home/index.html
#
#               image_path               css_data_path  \
# 0  data\raw\site_000.png  data\raw\site_000_css.json
# 1  data\raw\site_001.png  data\raw\site_001_css.json
#
#                                        layoutlm_data
# 0  {'words': ['amazon.ie', 'Delivering to Moate N...
# 1  {'words': ['UK Edition', 'Privacy Policy', 'Fe...
